# %% [markdown]
# <h1>Evan Lin(122367736) Artificial Intelligence Assignment</h1>
# <h1>Sri Lanka Vehicle Dataset</h1>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

from pandas.plotting import scatter_matrix
from seaborn import scatterplot, heatmap

from sklearn.model_selection import train_test_split

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

from sklearn.preprocessing import OneHotEncoder

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate

from sklearn.metrics import mean_absolute_error

from joblib import dump

# %%
import os
if 'google.colab' in str(get_ipython()):
  from google.colab import drive
  drive.mount('/content/drive')
  base_dir = "./drive/My Drive/Colab Notebooks/" # You may need to change this, depending on where your notebooks are on Google Drive
else:
  base_dir = "." # The dimensions
df.shape
# Out:
# (18936, 19)

# %% [markdown]
# <h1>Objectives</h1>
# <ul>
#     <li>Find the best model for vehicles sold in Sri Lanka</li>
#
# </ul>

# %% [markdown]
# <h1>Dataset Acquisition & Dataset Cleaning</h1>
# <p>The following dataset is provided by Prof. Derek Bridge from UCC</p>
# <p>We will be taking a deeper look into the dataset and perform analysis and cleaning that will be necessary</p>

# %%
# Use pandas to read the CSV file into a DataFrame
df = pd.read_csv(os.path.join(base_dir, "../datasets/dataset_vehicles.csv"))

# Shuffle the dataset
df = df.sample(frac=1, random_state=2)
df.reset_index(drop=True, inplace=True)

# %%
# The dimensions
df.shape
# Out:
# (18938, 19)

# %%
# Shows all features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18938 entries, 0 to 18937
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           18938 non-null  object
#  1   Sub_title       18938 non-null  object
#  2   Price           18938 non-null  object
#  3   Brand           18938 non-null  object
#  4   Model           18938 non-null  object
#  5   Edition         13908 non-null  object
#  6   Year            18938 non-null  int64
#  7   Condition       18938 non-null  object
#  8   Transmission    18938 non-null  object
#  9   Body            17043 non-null  object
#  10  Fuel            18938 non-null  object
#  11  Capacity        18938 non-null  object
#  12  Mileage         18938 non-null  object
#  13  Location        18938 non-null  object
#  14  Description     18938 non-null  object
#  15  Post_URL        18938 non-null  object
#  16  Seller_name     18938 non-null  object
#  17  Seller_type     18938 non-null  object
#  18  published_date  18938 non-null  object
# dtypes: int64(1), object(18)
# memory usage: 2.7+ MB

# %%
df.head()
# Out:
#                                            Title  \
# 0    Honda Fit Shuttle Full Option 2015 for sale
# 1  Kia Sorento 1 to 12 tan premium 2011 for sale
# 2                Suzuki Estilo Zen 2010 for sale
# 3                Micro MX 7 Mark 2 2013 for sale
# 4             Toyota Harrier LEXUS 2002 for sale
#
#                                            Sub_title         Price   Brand  \
# 0       Posted on 30 May 2:39 pm, Alutgama, Kalutara  Rs 5,600,000   Honda
# 1         Posted on 18 Jun 4:01 pm, Horana, Kalutara  Rs 9,800,000     Kia
# 2  Posted on 17 Mar 3:19 pm, Kuliyapitiya, Kurune...  Rs 2,175,000  Suzuki
# 3         Posted on 24 Jul 5:40 pm, Kottawa, Colombo  Rs 2,350,000   Micro
# 4         Posted on 23 Jul 8:32 pm, Negombo, Gampaha  Rs 5,390,000  Toyota
#
#          Model              Edition  Year Condition Transmission  \
# 0  Fit Shuttle          Full Option  2015      Used    Automatic
# 1      Sorento  1 to 12 tan premium  2011      Used    Automatic
# 2       Estilo           Zen Estilo  2010      Used       Manual
# 3         MX 7               Mark 2  2013      Used       Manual
# 4      Harrier                LEXUS  2002      Used    Automatic
#
#             Body    Fuel  Capacity     Mileage                    Location  \
# 0  Station wagon  Hybrid  1,490 cc  107,222 km         Alutgama,  Kalutara
# 1      SUV / 4x4  Diesel  2,200 cc  114,586 km           Horana,  Kalutara
# 2      Hatchback  Petrol  1,000 cc  134,000 km   Kuliyapitiya,  Kurunegala
# 3         Saloon  Petrol  1,500 cc   45,000 km           Kottawa,  Colombo
# 4      SUV / 4x4  Petrol  2,000 cc  170,000 km           Negombo,  Gampaha
#
#                                          Description  \
# 0  HONDA FIT SHUTTLE GP7Rs. 5,600,000/= (Negotiab...
# 1  sorento tan primium 1 -12 option engineer used...
# 2  New Tyres... New Battery ...Power Shutters..Po...
# 3   Motor CarRegistered on 2013 December First Owner
# 4  20023RD OWNERTOYOTA COMPANY MAINTAIN LEATHER E...
#
#                                             Post_URL             Seller_name  \
# 0  https://ikman.lk/en/ad/honda-fit-shuttle-full-...                   kasun
# 1  https://ikman.lk/en/ad/kia-sorento-1-to-12-tan...         Thilina Chamara
# 2  https://ikman.lk/en/ad/suzuki-estilo-zen-2010-...        Malith Welandage
# 3  https://ikman.lk/en/ad/micro-mx-7-mark-2-2013-...      Ravi Hettiarachchi
# 4  https://ikman.lk/en/ad/toyota-harrier-lexus-20...  NIROSHAN MOTOR TRADERS
#
#       Seller_type       published_date
# 0  Premium-Member  2021-05-30 14:39:00
# 1  Premium-Member  2021-06-18 16:01:00
# 2  Premium-Member  2021-03-17 15:19:00
# 3  Premium-Member  2021-07-24 17:40:00
# 4  Premium-Member  2021-07-23 20:32:00

# %%
# Summary statistics
df.describe(include="all")
# Out:
#                             Title  \
# count                       18938
# unique                      10329
# top     Suzuki Alto 2015 for sale
# freq                          184
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN
#
#                                             Sub_title       Price   Brand  \
# count                                           18938       18938   18938
# unique                                          17014        1831      57
# top     Posted on 03 Mar 11:21 am, Colombo 3, Colombo  Rs 650,000  Toyota
# freq                                               63          92    5762
# mean                                              NaN         NaN     NaN
# std                                               NaN         NaN     NaN
# min                                               NaN         NaN     NaN
# 25%                                               NaN         NaN     NaN
# 50%                                               NaN         NaN     NaN
# 75%                                               NaN         NaN     NaN
# max                                               NaN         NaN     NaN
#
#         Model  Edition          Year Condition Transmission       Body  \
# count   18938    13908  18938.000000     18938        18938      17043
# unique    516     6336           NaN         3            4          7
# top      Alto  G Grade           NaN      Used    Automatic  Hatchback
# freq      962      172           NaN     17991        11412       6712
# mean      NaN      NaN   2007.718344       NaN          NaN        NaN
# std       NaN      NaN     11.640139       NaN          NaN        NaN
# min       NaN      NaN   1927.000000       NaN          NaN        NaN
# 25%       NaN      NaN   2003.000000       NaN          NaN        NaN
# 50%       NaN      NaN   2012.000000       NaN          NaN        NaN
# 75%       NaN      NaN   2016.000000       NaN          NaN        NaN
# max       NaN      NaN   2021.000000       NaN          NaN        NaN
#
#           Fuel  Capacity     Mileage             Location  \
# count    18938     18938       18938                18938
# unique       6       432        3850                  198
# top     Petrol  1,500 cc  100,000 km   Kohuwala,  Colombo
# freq     13823      3861         450                 1333
# mean       NaN       NaN         NaN                  NaN
# std        NaN       NaN         NaN                  NaN
# min        NaN       NaN         NaN                  NaN
# 25%        NaN       NaN         NaN                  NaN
# 50%        NaN       NaN         NaN                  NaN
# 75%        NaN       NaN         NaN                  NaN
# max        NaN       NaN         NaN                  NaN
#
#                                               Description  \
# count                                               18938
# unique                                              17075
# top     * Leasing can be arranged with your requiremen...
# freq                                                  151
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  Post_URL     Seller_name  \
# count                                               18938           18938
# unique                                              17911            6103
# top     https://ikman.lk/en/ad/daihatsu-mira-es-led-fa...  LB Finance PLC
# freq                                                    4             512
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#            Seller_type       published_date
# count            18938                18938
# unique               1                15060
# top     Premium-Member  2021-03-03 11:21:00
# freq             18938                   69
# mean               NaN                  NaN
# std                NaN                  NaN
# min                NaN                  NaN
# 25%                NaN                  NaN
# 50%                NaN                  NaN
# 75%                NaN                  NaN
# max                NaN                  NaN

# %%
features = ["Title","Sub_title", "Price", "Brand", "Model", "Edition", "Year",
            "Condition", "Transmission", "Body", "Fuel", "Capacity", "Mileage", 
            "Location", "Description", "Post_URL", "Seller_name", "Seller_type", "publish_date"]

numeric_features = ["Price", "Mileage", "Year", "Capacity"]
nominal_features = ["Title","Sub_title", "Brand", "Model", "Edition", "Fuel",
            "Condition", "Transmission", "Body", "Location", "Description", "Post_URL", "Seller_name", "Seller_type", "published_date"]

# %%
# Looking into all values of nominal values
for feature in nominal_features:
    print(feature, df[feature].unique())
# Out:
# Title ['Honda Fit Shuttle Full Option 2015 for sale'
#  'Kia Sorento 1 to 12 tan premium 2011 for sale'
#  'Suzuki Estilo Zen 2010 for sale' ...
#  'Toyota Land Cruiser Prado Face Lift 2015 2010 for sale'
#  'Datsun Redi Go Used 2016 for sale' 'Nissan March Beatle 2002 for sale']
# Sub_title ['Posted on 30 May 2:39 pm, Alutgama, Kalutara'
#  'Posted on 18 Jun 4:01 pm, Horana, Kalutara'
#  'Posted on 17 Mar 3:19 pm, Kuliyapitiya, Kurunegala' ...
#  'Posted on 13 Feb 1:14 pm, Matugama, Kalutara'
#  'Posted on 11 Apr 4:55 pm, Delgoda, Gampaha'
#  'Posted on 15 Jul 7:31 am, Maharagama, Colombo']
# Brand ['Honda' 'Kia' 'Suzuki' 'Micro' 'Toyota' 'Nissan' 'Audi' 'Mitsubishi'
#  'Mercedes Benz' 'Peugeot' 'Zotye' 'Daihatsu' 'Hyundai' 'Perodua' 'BMW'
#  'Jaguar' 'Land Rover' 'Maruti Suzuki' 'Mazda' 'Lexus' 'Tata' 'MG' 'DFSK'
#  'Proton' 'Mini' 'Chery' 'Ford' 'Citroen' 'Isuzu' 'Volkswagen' 'Daewoo'
#  'Datsun' 'Volvo' 'Mahindra' 'Chrysler' 'Austin' 'Porsche' 'Other brand'
#  'Morris' 'Chevrolet' 'Maruti' 'Renault' 'Ssang Yong' 'Fiat' 'Subaru'
#  'Geely' 'Alfa Romeo' 'Hummer' 'Rover' 'Tesla' 'Moto Guzzi' 'Jeep'
#  'Aston Martin' 'Opel' 'Skoda' 'Smart' 'Vauxhall']
# Model ['Fit Shuttle' 'Sorento' 'Estilo' 'MX 7' 'Harrier' 'Maruti' 'March' 'Axio'
#  'Aqua' 'Wagon R Stingray' 'Hilux' 'Premio' 'Sunny' 'Soluna' 'A6' 'Vitz'
#  'Lancer' 'Alto' 'Prius' 'Hustler' 'E300' 'Land Cruiser Sahara' '407'
#  'C200' 'Corolla' 'Starlet' 'Extreme' 'Terios' 'Mira' 'Celerio' 'Stellar'
#  'Land Cruiser Prado' 'Avanza' 'A3' 'Baleno' 'E200' 'Grace' 'Leaf' 'Panda'
#  'Viva Elite' 'X1' 'XF' 'Swift' 'Vezel' 'Range Rover Sport' 'Boon' 'A1'
#  '800' 'Other Model' 'NX' 'Fit' 'X-Trail' 'Bluebird' 'Butterfly' 'Dutsun'
#  'Charmant' 'Spacia' 'CLA 200' 'Civic' 'Montero' 'Corona' 'Wagon R'
#  'Xenon' 'ZS' 'Glory' 'Fit Aria' 'Allion' 'AD Wagon' 'Saga' 'Wigo' 'CRV'
#  'Familia' 'Rio' 'A4' 'CHR' 'Cooper' 'QQ' 'Carina' 'NX300H' 'Insight'
#  'Raptor Ranger' 'Outlander' 'Vios' 'Nano' '740Le' 'Accord' 'Passo'
#  'Sportage' 'Beetle' 'Zen' 'Wagon R FZ' 'Pajero' 'Fielder' 'E220' '4DR'
#  'Belta' 'Raize' 'Polo' 'Ranger' '523i' 'C180' 'Wagon R FX' 'Panda Cross'
#  'L200' 'i8' 'Eon' 'Dayz' 'Redi Go' 'C350' '850' 'Laser' 'Bolero' 'Patrol'
#  'Range Rover' 'Bighorn' 'X3' 'eK Space' '520d' 'Camry' 'Kyron' 'City'
#  'Roomy' 'A8' 'Rush' 'Charade' 'S320' 'X5' 'Range Rover Velar' 'Axia'
#  'Sylphy' 'Discovery Sport' '208' 'Matrix' '300' 'Tank' 'Rocky' '6'
#  'Cefiro' 'Mini Cooper' 'Eclipse Cross' 'J24' 'Discovery' 'Defender'
#  'Copen' 'Santa Fe' 'Cayenne' 'Elantra' 'SAI' 'Bora' 'A-Star' 'Trend'
#  'Accent' 'Esquire' 'Freed' 'Cultus' '3008' 'Caldina' 'Serena' 'Ceres'
#  'Wingroad' 'Countryman' 'Other model' 'S660' 'ActiveHybrid 7' 'Minor'
#  'Cast Activa' '5008' 'S60' 'Liana' 'Terracan' 'IST' 'Trajet' 'i20'
#  'Xpander' 'Indica' '318i' 'CLA 180' 'Pixis' 'Hijet' 'Freelander' 'ML270'
#  'Cruze' 'Rexton' 'E350' 'Picanto' 'Auris' 'Grand Vitara' 'Sumo' 'Cami'
#  'Savvy' 'C220' '406' 'Pulsar' 'Kelisa' 'Q2' 'KWID' 'CLS' 'Galant' 'Bezza'
#  'soul' 'Korando' 'Punto' 'Sonata' 'Esse' 'Alphard' 'Crown' 'E250'
#  'Tercel' '740e' 'Fortuner' 'ML350' 'N-Box' 'Stonic' 'Tiida' 'Forester'
#  'Wira' 'Wake' 'N-WGN' 'Axela' 'Navara' 'Demio' 'GLE 300D' 'Excel'
#  'Range Rover Evoque' 'Tanto' '2' 'Z4' 'CT-200H' 'Trooper' 'S-Cross'
#  '525i' '320d' 'Shogun' 'Crossroad' 'A5' 'Tivoli' 'RX' 'Actyon' 'Yaris'
#  'Voxy' 'i3' 'Tucson' 'HS250H' 'STI' 'Dualis' '940' 'Carol' 'Corsa' 'GT86'
#  '320i' 'Q7' 'H3' 'Sprinter' 'Grand i10' 'Q3' 'Jimny' 'Marino' 'Vitara'
#  'Mustang' 'Geely' 'Nexon' 'Airwave' 'XV' 'Atrai Wagon' 'Nomad' 'RAV4'
#  'eK Wagon' 'S300' 'Move' 'Esteem' 'Escudo' 'RX400' 'Waja' 'WagonR'
#  'Gemini' 'S350' 'ASX' 'Fulwin' 'C300' 'B250e' 'Model S' 'Mirage' 'Juke'
#  'Linea' 'A180' 'Golf' 'Astina' '405' 'Mini' 'Z100' 'Attrage' '3' 'Indigo'
#  'C250' 'Festiva' 'Tiggo' 'Kancil' 'Oxford' 'Mark' 'Jetta' 'Skyline'
#  'Fairlady Z' 'Libero' 'Colt' 'CX-5' '430i' 'Uno' 'ActiveHybrid 5' '2008'
#  'Jade' '740Li' 'X5 eDrive' 'Verossa' 'X250d' 'Lifan' 'Leganza' '530e'
#  'Etios' '305' '206' '218i' 'Duet' '520i' '508' 'S560' 'Aveo' 'Sephia'
#  'Cherokee' 'Safari' 'MU-X' 'Strada' 'Kenari' 'Celica' '740d' 'Qashqai'
#  'E240' 'Primera' 'Flair' 'Zest' 'Presea' 'GenX Nano' 'S80' 'F50' 'Santro'
#  'Passat' '330i' 'Beat' 'F-150' 'Platz' 'Jazz' 'Ertiga' 'Sienta' 'Terrano'
#  'Scorpio' 'RVR' 'Cambridge' 'HR-V' 'Venue' 'Impreza' 'Persona' 'Fiesta'
#  'MR-S' 'Emgrand' 'XE' 'Integra' 'Micra' '730d' 'CRZ' 'Ignis' 'Telcolin'
#  'Korondo' 'Rhino' 'Lanos' 'Focus' 'GLB' 'S400' 'Dzire' 'Spectra' 'Cuore'
#  'Cedia' '404' 'V27' '4Runner' 'XBee' 'VW1300' 'Astra' 'Superb' '607'
#  'S40' 'Panamera' 'Nubira' '308' '2 Skyactive' 'X5 M' 'BAIC' '735i'
#  'Vanguard' 'SX4' 'RX350' 'A200' 'X2' 'Chariot' 'Atos' 'Macan' 'BB'
#  'Grand Cherokee' 'BT-50' 'S-Type' 'K900' 'X-Type' 'EK Custom' 'Musso'
#  '100' 'Aventura' 'Ciaz' 'Carens' 'FJ Cruiser' '7' '528i' 'Wrangler'
#  'Kuga' 'Omega' '370Z' 'Teana' 'Everest' 'F-Pace' 'Runx' 'QQ3' 'Spark'
#  'Tribute' 'Range Rover PHEV' '730Ld' 'Q5' 'M3' '116i' 'UP' 'Logo' '316i'
#  'MOCO' 'C160' 'XC90' 'Jonway' 'H2' '505' 'Legacy' 'Altis' 'Ecosport'
#  '735Li' 'Tiguan' 'Note' 'Junior' 'X25' 'Quanto' 'Smart cab' 'SLC 180'
#  'Cerato' 'S500' 'e-NV200' '718 Cayman' '330e' '530i' 'Spike' '104' 'A150'
#  'Sedona' 'Thor' 'GLE 400' 'Espero' 'Mentor' 'D-Max' 'Mondeo' 'Towny' 'R2'
#  'Concerto' 'Carnival' 'e2o' 'Cynos' 'Avalon' '530d' 'Delica' 'Clarus'
#  'GLA 200' 'GLA 180' 'Forfour' 'Gloria' 'Frontera' '190D' 'i-MiEV' 'E180'
#  'E46' "Fit She's" 'Odyssey' '225XE' 'ML320' 'Leeza' '5' 'Fabia' 'F-Type'
#  'Privilage' 'Viva' 'Optima' 'Voleex' 'Panther' 'Avensis' 'M6' 'Fortwo'
#  'Solio' 'MX-5' 'Cross' 'FTO' '730iL' 'Vellfire' 'Compass' '718 Boxter'
#  'E-Pace' 'WRX']
# Edition ['Full Option' '1 to 12 tan premium' 'Zen Estilo' ... 'UK Model 2018'
#  'Face Lift 2015' 'Beatle']
# Fuel ['Hybrid' 'Diesel' 'Petrol' 'Electric' 'Other fuel type' 'CNG']
# Condition ['Used' 'New' 'Reconditioned']
# Transmission ['Automatic' 'Manual' 'Tiptronic' 'Other transmission']
# Body ['Station wagon' 'SUV / 4x4' 'Hatchback' 'Saloon' nan 'MPV'
#  'Coup̩/Sports' 'Convertible']
# Location [' Alutgama,  Kalutara' ' Horana,  Kalutara' ' Kuliyapitiya,  Kurunegala'
#  ' Kottawa,  Colombo' ' Negombo,  Gampaha' ' Kandy,  Kandy'
#  ' Kiribathgoda,  Gampaha' ' Ja-Ela,  Gampaha' ' Colombo 5,  Colombo'
#  ' Talawatugoda,  Colombo' ' Elpitiya,  Galle' ' Kegalle,  Kegalle'
#  ' Athurugiriya,  Colombo' ' Matale,  Matale' ' Ragama,  Gampaha'
#  ' Piliyandala,  Colombo' ' Colombo 2,  Colombo' ' Kohuwala,  Colombo'
#  ' Bandaragama,  Kalutara' ' Nugegoda,  Colombo' ' Kotte,  Colombo'
#  ' Colombo 3,  Colombo' ' Boralesgamuwa,  Colombo' ' Akkarepattu,  Ampara'
#  ' Matara,  Matara' ' Moratuwa,  Colombo' ' Malabe,  Colombo'
#  ' Kolonnawa,  Colombo' ' Kadawatha,  Gampaha' ' Hatton,  Nuwara Eliya'
#  ' Anuradhapura,  Anuradhapura' ' Dehiwala,  Colombo' ' Hakmana,  Matara'
#  ' Colombo 4,  Colombo' ' Homagama,  Colombo' ' Gampaha,  Gampaha'
# Seller_name ['kasun' 'Thilina Chamara' 'Malith Welandage' ... 'smart security'
#  'Gokulesh Soundararajah' 'Ramanayake']
# Seller_type ['Premium-Member']
# published_date ['2021-05-30 14:39:00' '2021-06-18 16:01:00' '2021-03-17 15:19:00' ...
#  '2021-07-05 13:48:00' '2021-02-13 13:14:00' '2021-04-11 16:55:00']

# %% [markdown]
# <h2>Looking at missing values</h2>
# <p>As we show above, it seems like there are missing values in "Body" & "Edition"</p>
# <p>Let's have a look at both of these values a bit more in depth</p>

# %% [markdown]
# <h3>Missing values in "Body"</h3>

# %%
print(df["Body"].unique())
# Out:
# ['Station wagon' 'SUV / 4x4' 'Hatchback' 'Saloon' nan 'MPV'
#  'Coup̩/Sports' 'Convertible']

# %%
df[df["Body"].isnull()]
# Out:
#                                                 Title  \
# 6                          Nissan March 2000 for sale
# 12                    Nissan Sunny B 11 1984 for sale
# 26                      Suzuki Alto K10 2015 for sale
# 28                       Toyota Corolla 1985 for sale
# 55                Honda Vezel Z package 2014 for sale
# ...                                               ...
# 18884                        Tata Xenon 2015 for sale
# 18887                 Nissan Sunny B210 1982 for sale
# 18919                Austin Mini Cooper 1960 for sale
# 18921                 Micro Panda Cross 2016 for sale
# 18922  Daihatsu Charade Maruti 15 Japan 1984 for sale
#
#                                                Sub_title         Price  \
# 6                Posted on 05 Jul 11:10 am, Kandy, Kandy  Rs 2,260,000
# 12             Posted on 23 Jun 3:13 pm, Elpitiya, Galle    Rs 650,000
# 26          Posted on 21 Jun 2:24 pm, Colombo 3, Colombo  Rs 2,895,000
# 28         Posted on 28 Jun 2:42 pm, Akkarepattu, Ampara    Rs 600,000
# 55          Posted on 09 Mar 2:29 pm, Colombo 3, Colombo  Rs 5,350,000
# ...                                                  ...           ...
# 18884  Posted on 03 Aug 6:11 pm, Kuliyapitiya, Kurune...  Rs 2,100,000
# 18887  Posted on 08 Jul 10:26 am, Kuliyapitiya, Kurun...    Rs 430,000
# 18919      Posted on 12 Mar 11:01 am, Kalutara, Kalutara  Rs 1,075,000
# 18921      Posted on 09 Aug 12:51 pm, Panadura, Kalutara  Rs 2,795,000
# 18922     Posted on 26 Mar 4:32 pm, Piliyandala, Colombo    Rs 475,000
#
#           Brand        Model          Edition  Year Condition Transmission  \
# 6        Nissan        March              NaN  2000      Used    Automatic
# 12       Nissan        Sunny             B 11  1984      Used       Manual
# 26       Suzuki         Alto              K10  2015      Used    Automatic
# 28       Toyota      Corolla              NaN  1985      Used       Manual
# 55        Honda        Vezel       Z package   2014      Used    Automatic
# ...         ...          ...              ...   ...       ...          ...
# 18884      Tata        Xenon            Xenon  2015      Used    Automatic
# 18887    Nissan        Sunny             B210  1982      Used       Manual
# 18919    Austin  Mini Cooper              NaN  1960      Used       Manual
# 18921     Micro  Panda Cross              NaN  2016      Used       Manual
# 18922  Daihatsu      Charade  Maruti 15 Japan  1984      Used       Manual
#
#       Body    Fuel  Capacity     Mileage                    Location  \
# 18919  2021-03-12 11:01:00
# 18921  2021-08-09 12:51:00
# 18922  2021-03-26 16:32:00
#
# [1895 rows x 19 columns]

# %% [markdown]
# <h3>Missing values in "Edition"</h3>

# %%
print(df["Edition"].unique())
# Out:
# ['Full Option' '1 to 12 tan premium' 'Zen Estilo' ... 'UK Model 2018'
#  'Face Lift 2015' 'Beatle']

# %%
print(df["Edition"].unique().tolist())
# Out:
# ['Full Option', '1 to 12 tan premium', 'Zen Estilo', 'Mark 2', 'LEXUS', '800', nan, 'G Grade', '3L AUTO CHAMP', 'G Superior', 'B 11', 'Toyota Soluna', '2.0T', '1982', 'Alto', 'Alpha 7 Seater CX', 'Bluetec hybrid AMG', 'ZX BRUNO LIMITED', 'K10', 'G Superior F EX', 'Diesel', 'Premium Plus AMG', 'Push Start', 'EP91 GLANZA V ', 'Safety Edition', 'Limited Edition Jeep', 'S Grade 2012', '3rd Generation', 'Automatic 4 wheel', 'Es | Full option', '1300 cc', 'WXB/Hybrid', 'vxi Auto', 'GSL', 'Diesel TX Limited', 'S-line', '301', 'Safety', '-', 'SILVER', 'Facelifted Msport', 'Diesel 2.0', 'Z package ', 'HSE DIESEL', 'S', 'TFSI', 'MARUTI 800 SPECIAL', 'Deluxe', 'SAFETY ', 'Edition 2', 'RS Sensing', 'AGZ10 ', 'Safety Edition 02', 'X Line', 'GP5 L', 'S Line', 'Nissan Sunny GL', 'Daihatsu', 'Suzuki', 'Modellista', 'Japan', 'Axio Fielder', 'Zen', 'Stingray', 'Jeep', '1984', '2016 7 SEATS', '2018', '2008 Limited', '301-8810', 'LXI', '1988', 'Custom / Turbo', 'V TEC Turbo', 'ES Push Start', '323', 'S Grade', 'Smart Cab 2010', '121 X LIMITED AUTO', 'Suzuki alto 2015', 'DX Wagon', 'G sport G sport', 'Avantgarde', 'Bluebird', 'TFSi Sports Turbo', 'Austin Rover 1000', 'AXIO X LIMITED ', 'GP4 RS', 'B11', 'Z BLACK', 'GT sport', 'Hover', 'F-Ex (G-Superior)', 'TX 150', 'ES', 'c12A', 'ES LED Facelift', 'Ford Ranger Raptor', 'Prado Diesel', '7 SEATER PETROL 2L', 'Xsara', 'HDJ81', 'VELAR R Dynamic HSE', 'Cab 2wd', 'S GRADE', '(Used)', 'Ex Saloon', 'Full Optional', 'M-Sport', 'Honda Accord RS', '2012', 'Toyota Vitz', 'AMG Coupe', '1st Owner', 'Wagon R Stingray', '7Seat', 'Safety 4 Way Camera', 'Vxi Auto', 'Toyota', 'GLS', 'AMG', '4WD PHEV', '1.3 Push start', 'DX KE 72', 'AK 12', 'G Limited', 'AE 100', 'Turbo', 'Micro', 'Vigo Single Ab', 'LIMITED EDITION', '1987', 'ex 1983', 'Maruti', 'UNREGISTERED', 'R~Line', 'RS Turbo', 'New Model', '2010 3 OPTION', 'Auto Gear', 'Toyota Axio Hybrid', 'Mitsubishi', 'Limited Edition', 'Z grade', 'TXL', 'XM', 'Racer', 'premium auto', '2 Air Bags', 'HSE Pure Diesel', 'Sportero', 'Fully Loaded', '141', 'G superior', 'Safety.key', 'Premium Plus', 'GP5 L Safety Pack', 'Premium', 'EX PACKAGE', 'Ex-Sensing', 'GP5 L Grade', 'Vitz 2008', 'Nissan Dayz Safety', 'Special edition', 'FB 15', 'AUTOMATIC  ABS  BJ5', 'Sports Back', 'Sunny', 'luxury', '2011', 'KE20', 'TRJ 150 Diesel', 'Mahindra', 'ZXI', 'AUTOBIOGRAPHY PHEV', 'C11 V', 'Safety editionpack', 'GP 5 S Grade', 'C12', 'Vitz', 'Petrol/ 7 Seater', 'Dimo Maintained', '1985', 'Premium Hybrid', 'smart', 'M Sport Fully Loaded', 'S LED Limited', 'Custom', '(PAJERO)', 'F10', 'G Plus', 'Swift car Dankotuwa', '2007', 'PHEV G - Safety', '5 Gear box', 'HB11', 'F SAFETY', '800 LXI', 'X-Turbo JStyle 2', 'TX 6FWD', 'Japan Unregistered', 'L LWB 4.2L Quattro', 'EF2', '2nd generation', 'K12 Automatic Japan', 'Camry Hybrid', 'Hilux double cab', 'Stingray Turbo', 'Dihatsu Quric', '2015', 'Tx JTE150 Diesel', 'sorento 1to7 option', 'Super Saloon', 'Bighorn', 'RS', 'JAPAN RS WORKS', 'G 11', 'W140', 'First Owner', 'G', 'Custom Z TURBO', 'Brown', 'Double Cab 4x4', 'Magna plus', '2008', 'G Frontier', 'HSE LUXURY', '208', 'Y61', 'EE111', 'Alto 800 LXI', 'luxury version auto', '800cc', '4WD Jeep', 'Sport', 'K12', 'C', 'Manual', 'Gs Safety', '1300', 'RS SENSING', 'Feroza', 'Bluetec Hybrid', 'SPORTS EFI', 'japan', 'S Line Sedan', 'Autobiography B/New', 'cx', 'Champ', 'N16 Menuwal', 'K 12', 'GL 4fd', 'GT Turbo', 'Evoque', 'XL SAFETY BEIGE', 'LN 107 SSR-X Hilux', 'full  options', 'L Japan unregistered', 'Sport GLS DIESEL', '4dr5', 'CK 2 Turbo', 'EX Package ', 'NZT260', '110 Station Wagon', 'Toyota Passo Racy', 'X play Sport', 'UZJ200 V8 ZX', 'Auto', 'Sport 1988', 'NON SAFETY KEY START', 'Passo', 'FB 14', 'FB15 Car', 'Master Piece', 'V6 Double Cab', 'Company Maintain', '120 Prado', 'X Urban', 'FD3 Silver', 'Belta', 'Turbo S Hybrid', 'D21', 'full', 'B211', 'Cross over', '16000KMs', '2017', 'Dual Air Bags', 'Vxi Sport Limited', 'Luxury', 'P/S', 'tata', 'G grade 2014', 'Aus Spec Highest', '2004', 'GP5 Highest Grade', ...

# %%
df[df["Edition"].isnull()]
# Out:
#                                        Title  \
# 6                 Nissan March 2000 for sale
# 7                  Toyota Axio 2015 for sale
# 9      Suzuki Wagon R Stingray 2018 for sale
# 15                 Toyota Vitz 2017 for sale
# 19              Suzuki Hustler 2016 for sale
# ...                                      ...
# 18907            Suzuki Maruti 2006 for sale
# 18915              Honda Vezel 2018 for sale
# 18918        Daihatsu Charmant 1981 for sale
# 18919       Austin Mini Cooper 1960 for sale
# 18921        Micro Panda Cross 2016 for sale
#
#                                              Sub_title         Price  \
# 6              Posted on 05 Jul 11:10 am, Kandy, Kandy  Rs 2,260,000
# 7      Posted on 08 Apr 8:48 pm, Kiribathgoda, Gampaha  Rs 5,600,000
# 9        Posted on 25 Jul 11:08 am, Colombo 5, Colombo  Rs 5,300,000
# 15         Posted on 12 Apr 12:05 pm, Negombo, Gampaha  Rs 5,100,000
# 19      Posted on 30 Jun 9:37 am, Piliyandala, Colombo  Rs 3,560,000
# ...                                                ...           ...
# 18907    Posted on 06 Apr 7:27 pm, Akkarepattu, Ampara  Rs 1,360,000
# 18915    Posted on 09 Apr 10:49 am, Panadura, Kalutara  Rs 8,675,000
# 18918   Posted on 01 Aug 12:53 am, Katunayake, Gampaha    Rs 280,000
# 18919    Posted on 12 Mar 11:01 am, Kalutara, Kalutara  Rs 1,075,000
# 18921    Posted on 09 Aug 12:51 pm, Panadura, Kalutara  Rs 2,795,000
#
#           Brand             Model Edition  Year Condition Transmission  \
# 6        Nissan             March     NaN  2000      Used    Automatic
# 7        Toyota              Axio     NaN  2015      Used    Automatic
# 9        Suzuki  Wagon R Stingray     NaN  2018      Used    Automatic
# 15       Toyota              Vitz     NaN  2017      Used    Automatic
# 19       Suzuki           Hustler     NaN  2016      Used    Automatic
# ...         ...               ...     ...   ...       ...          ...
# 18907    Suzuki            Maruti     NaN  2006      Used       Manual
# 18915     Honda             Vezel     NaN  2018      Used    Automatic
# 18918  Daihatsu          Charmant     NaN  1981      Used       Manual
# 18919    Austin       Mini Cooper     NaN  1960      Used       Manual
# 18921     Micro       Panda Cross     NaN  2016      Used       Manual
#
#                 Body    Fuel  Capacity     Mileage                 Location  \
# 6                NaN  Petrol  1,000 cc  140,000 km            Kandy,  Kandy
# 7             Saloon  Petrol  1,500 cc  132,400 km   Kiribathgoda,  Gampaha
# 9          Hatchback  Hybrid    650 cc   13,800 km      Colombo 5,  Colombo
# 15            Saloon  Petrol  1,000 cc   26,000 km        Negombo,  Gampaha
# 19         Hatchback  Petrol    660 cc   70,000 km    Piliyandala,  Colombo
# ...              ...     ...       ...         ...                      ...
# 18907      Hatchback  Petrol    800 cc  118,000 km     Akkarepattu,  Ampara
# 18915  Station wagon  Petrol  1,500 cc   80,000 km      Panadura,  Kalutara
# 18918         Saloon  Petrol  1,200 cc   60,000 km     Katunayake,  Gampaha
# 18919            NaN  Petrol    850 cc  200,000 km      Kalutara,  Kalutara
# 18921            NaN  Petrol  1,300 cc   35,000 km      Panadura,  Kalutara
#
#                                              Description  \
# 6      * Location - Hedeniya Nissn March* YOM 2000* Y...
# 7      First owner ,used by lawyer in mint condition ...
# 9      Suzuki Wagon R Stingray Safety 2018Used , exce...
# 15     Toyota Vitz YOM 2017Pearl white26000 km1000cc1...
# 19     Suzuki Hustler 2016=================* Location...
# ...                                                  ...
# 18907                             Central lock Allowheel
# 18915  AIR CONDITION POWER STEERING POWER MIRROR POWE...
# 18918  Running 100%.All light work.New battery.Paint ...
# 18919                  Good Runing condition New battery
# 18921  2nd owner Power shutters/ power mirrors Center...
#
#                                                 Post_URL  \
# 6      https://ikman.lk/en/ad/nissan-march-2000-for-s...
# 7      https://ikman.lk/en/ad/toyota-axio-2015-for-sa...
# 9      https://ikman.lk/en/ad/suzuki-wagon-r-stingray...
# 15     https://ikman.lk/en/ad/toyota-vitz-2017-for-sa...
# 19     https://ikman.lk/en/ad/suzuki-hustler-2016-for...
# ...                                                  ...
# 18907  https://ikman.lk/en/ad/suzuki-maruti-2006-for-...
# 18915  https://ikman.lk/en/ad/honda-vezel-2018-for-sa...
# 18918  https://ikman.lk/en/ad/daihatsu-charmant-1981-...
# 18919  https://ikman.lk/en/ad/austin-mini-cooper-1960...
# 18921  https://ikman.lk/en/ad/micro-panda-cross-2016-...
#
#                                 Seller_name     Seller_type  \
# 6        Sell Fast | Kandy | Easy Buy Lanka  Premium-Member
# 7                       Saranga Pathiranage  Premium-Member
# 9                                     Muffi  Premium-Member
# 15                           Royanaa Motors  Premium-Member
# 19                                 Tele Ads  Premium-Member
# ...                                     ...             ...
# 18907                                 sajee  Premium-Member
# 18915  Sellfast | Piliyandala |New City Adz  Premium-Member
# 18918                             K. perera  Premium-Member
# 18919                              harshana  Premium-Member
# 18921                          Mr. Fernando  Premium-Member
#
#             published_date
# 6      2021-07-05 11:10:00
# 7      2021-04-08 20:48:00
# 9      2021-07-25 11:08:00
# 15     2021-04-12 12:05:00
# 19     2021-06-30 09:37:00
# ...                    ...
# 18907  2021-04-06 19:27:00
# 18915  2021-04-09 10:49:00
# 18918  2021-08-01 00:53:00
# 18919  2021-03-12 11:01:00
# 18921  2021-08-09 12:51:00
#
# [5030 rows x 19 columns]

# %% [markdown]
# <h2>Conclusion</h2>
# <p>It seems that cars with null descriptions for Body and Edition have all the other features listed in. I have decided to leave the dataset as a whole without deleted any columns for now.</p>
# <p>While cleaning the dataset</p>
# <ul>
#     <li>The decision was made to not delete any of the datasets for now</li>
#     <li>All numeric values that is as type object will be casted to type int</li>
# </ul>

# %%
for feature in ["Price", "Mileage", "Capacity"]:
    df[feature] = (
        df[feature]
        .astype(str)                                 
        .str.replace(r"[^\d]", "", regex=True)        
        .replace("", np.nan)                          
        .astype("int64")                             
    )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18938 entries, 0 to 18937
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           18938 non-null  object
#  1   Sub_title       18938 non-null  object
#  2   Price           18938 non-null  int64
#  3   Brand           18938 non-null  object
#  4   Model           18938 non-null  object
#  5   Edition         13908 non-null  object
#  6   Year            18938 non-null  int64
#  7   Condition       18938 non-null  object
#  8   Transmission    18938 non-null  object
#  9   Body            17043 non-null  object
#  10  Fuel            18938 non-null  object
#  11  Capacity        18938 non-null  int64
#  12  Mileage         18938 non-null  int64
#  13  Location        18938 non-null  object
#  14  Description     18938 non-null  object
#  15  Post_URL        18938 non-null  object
#  16  Seller_name     18938 non-null  object
#  17  Seller_type     18938 non-null  object
#  18  published_date  18938 non-null  object
# dtypes: int64(4), object(15)
# memory usage: 2.7+ MB

# %%
# Showcasing we have casted type object to type int64
df.head()
# Out:
#                                            Title  \
# 0    Honda Fit Shuttle Full Option 2015 for sale
# 1  Kia Sorento 1 to 12 tan premium 2011 for sale
# 2                Suzuki Estilo Zen 2010 for sale
# 3                Micro MX 7 Mark 2 2013 for sale
# 4             Toyota Harrier LEXUS 2002 for sale
#
#                                            Sub_title    Price   Brand  \
# 0       Posted on 30 May 2:39 pm, Alutgama, Kalutara  5600000   Honda
# 1         Posted on 18 Jun 4:01 pm, Horana, Kalutara  9800000     Kia
# 2  Posted on 17 Mar 3:19 pm, Kuliyapitiya, Kurune...  2175000  Suzuki
# 3         Posted on 24 Jul 5:40 pm, Kottawa, Colombo  2350000   Micro
# 4         Posted on 23 Jul 8:32 pm, Negombo, Gampaha  5390000  Toyota
#
#          Model              Edition  Year Condition Transmission  \
# 0  Fit Shuttle          Full Option  2015      Used    Automatic
# 1      Sorento  1 to 12 tan premium  2011      Used    Automatic
# 2       Estilo           Zen Estilo  2010      Used       Manual
# 3         MX 7               Mark 2  2013      Used       Manual
# 4      Harrier                LEXUS  2002      Used    Automatic
#
#             Body    Fuel  Capacity  Mileage                    Location  \
# 0  Station wagon  Hybrid      1490   107222         Alutgama,  Kalutara
# 1      SUV / 4x4  Diesel      2200   114586           Horana,  Kalutara
# 2      Hatchback  Petrol      1000   134000   Kuliyapitiya,  Kurunegala
# 3         Saloon  Petrol      1500    45000           Kottawa,  Colombo
# 4      SUV / 4x4  Petrol      2000   170000           Negombo,  Gampaha
#
#                                          Description  \
# 0  HONDA FIT SHUTTLE GP7Rs. 5,600,000/= (Negotiab...
# 1  sorento tan primium 1 -12 option engineer used...
# 2  New Tyres... New Battery ...Power Shutters..Po...
# 3   Motor CarRegistered on 2013 December First Owner
# 4  20023RD OWNERTOYOTA COMPANY MAINTAIN LEATHER E...
#
#                                             Post_URL             Seller_name  \
# 0  https://ikman.lk/en/ad/honda-fit-shuttle-full-...                   kasun
# 1  https://ikman.lk/en/ad/kia-sorento-1-to-12-tan...         Thilina Chamara
# 2  https://ikman.lk/en/ad/suzuki-estilo-zen-2010-...        Malith Welandage
# 3  https://ikman.lk/en/ad/micro-mx-7-mark-2-2013-...      Ravi Hettiarachchi
# 4  https://ikman.lk/en/ad/toyota-harrier-lexus-20...  NIROSHAN MOTOR TRADERS
#
#       Seller_type       published_date
# 0  Premium-Member  2021-05-30 14:39:00
# 1  Premium-Member  2021-06-18 16:01:00
# 2  Premium-Member  2021-03-17 15:19:00
# 3  Premium-Member  2021-07-24 17:40:00
# 4  Premium-Member  2021-07-23 20:32:00

# %% [markdown]
# <h2>Comparing numeric features with price</h2>
# <p>We will compare numeric features with the price in a 2D array to look for outliers</p>

# %%
plot = scatterplot(x="Mileage", y="Price", data=df)

# %%
plot = scatterplot(x="Year", y="Price", data=df)

# %%
plot = scatterplot(x="Condition", y="Price", data=df)

# %%
plot = scatterplot(x="Capacity", y="Price", data=df)

# %% [markdown]
# <h2>Deeper look into overpriced cars</h2>
# <p>There is a re-occuring theme where the prices of cars in SRI Lanka are >= 150million RS</p>
# <p>As shown below a used car with high mileog having prices above 150m RS seems kind of insane. We will remove these examples from our dataset.</p>

# %%
df[(df["Price"] >= 150000000)]
# Out:
#                                       Title  \
# 583   Toyota Premio 1st owner 2020 for sale
# 9227   Mitsubishi Montero GLS 2015 for sale
#
#                                            Sub_title      Price       Brand  \
# 583   Posted on 25 Jul 6:36 am, Nattandiya, Puttalam  179000000      Toyota
# 9227   Posted on 01 Jul 1:38 pm, Nittambuwa, Gampaha  210000000  Mitsubishi
#
#         Model         Edition  Year Condition Transmission       Body    Fuel  \
# 583    Premio  1st owner 2020  2020      Used    Automatic     Saloon  Petrol
# 9227  Montero             GLS  2015      Used    Automatic  SUV / 4x4  Diesel
#
#       Capacity  Mileage                Location  \
# 583       1500    18000   Nattandiya,  Puttalam
# 9227      3200    80000    Nittambuwa,  Gampaha
#
#                                             Description  \
# 583   Toyota Premio G SuperiorManufacture Year 2020E...
# 9227  First owner, Leather seat, Electric srat, Rock...
#
#                                                Post_URL  \
# 583   https://ikman.lk/en/ad/toyota-premio-1st-owner...
# 9227  https://ikman.lk/en/ad/mitsubishi-montero-gls-...
#
#                 Seller_name     Seller_type       published_date
# 583      HRN Communications  Premium-Member  2021-07-25 06:36:00
# 9227  Ranaweera Enterprises  Premium-Member  2021-07-01 13:38:00

# %% [markdown]
# <p>A used car being more than 150million RS with high mileage seems a bit extreme in our dataset. So we will drop these 2 to clean our dataset</p>

# %%
# Delete examples where price are NaN
df.dropna(subset=["Price"], inplace=True)

# Delete examples whose prices are too high
df = (df[(df["Price"] <= 150000000)]).copy()

# Reset the indez
df.reset_index(drop=True, inplace=True)

# Check the invalid data was filtered out
df.shape
# Out:
# (18936, 19)

# %%
plot = scatterplot(x="Capacity", y="Price", data=df)

# %%
plot = scatterplot(x="Condition", y="Price", data=df)

# %% [markdown]
# <h2>Conclusion</h2>
# <p>It seems that cars with null values for Body and Edition have all the other features listed in. I have decided to leave those in the dataset.</p>
# <p>While cleaning the dataset</p>
# <ul>
#     <li>The decision was made to only delete rows where the prices are absurdly high</li>
#     <li>All numeric values that is as type object has been casted to type int</li>
# </ul>
# <p>In total we have only deleted 2 examples, while keeping the remaining for dev and test set</p>
#
# <h3>Some remarks</h3>
# <p>Personally would like to delete useless features such as title, subtitle, description. However these will be kept for now as we can drop them later in feature engineering abfter getting our first evaluation from the developement set</p>

# %% [markdown]
# <h1>Create a Test Set</h1>
# <ul>
#     <li>Split off a test set. (80%, 20%)</li>
#     <li>Split development set into train and validation sets (75%/25%)</li>
# </ul>

# %%
# Split off the test set: 20% of the dataset.
dev_df, test_df = train_test_split(df, train_size=0.8, random_state=2)

# %%
copy_df = dev_df.copy()
m = scatter_matrix(copy_df, figsize=(15, 15))
